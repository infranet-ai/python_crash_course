# %% [markdown]
# <a href="https://colab.research.google.com/github/infranet-ai/python_crash_course/blob/main/practicepython_org.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Character Input

# Create a program that asks the user to enter their name and their age. Print out a message addressed to them that tells them the year that they will turn 100 years old.

import datetime

name = input("enter the input name")

age = int(input("enter the age current"))

current_year = datetime.datetime.now().year
year_at_100 = current_year + (100 - age)

# Print the result
print(f"Hi {name}, you will turn 100 years old in the year {year_at_100}!")
# Out:
# enter the input namesat
# enter the age current48
# Hi sat, you will turn 100 years old in the year 2078!

# %%
# Odd Or Even

# Ask the user for a number. Depending on whether the number is even or odd, print out an appropriate message


num = input("enter a number")

mod = num % 2

if mod > 0 :

    print("you picked odd number")

else:

    print("you picked even number")
